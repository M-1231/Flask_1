# %%
"""Q.1
   Flask is a web framework that allows us to build lightweight web applications quickly and easily with Python. A web framework is a set of tools and libraries that help you create and manage web applications, such as handling requests, rendering templates, and connecting to databases.
   Flask is considered a micro-framework, which means that it has minimal dependencies on external libraries and gives you more flexibility and control over your web development.

   Advantages of Flask are:
    It is versatile and can be used for various types of web applications, such as blogs, e-commerce, social media, etc.
    It is affordable and free of charge, as it is open-source and has a large community of developers who contribute to its development and support.
    It is easy to find developers who are familiar with Flask, as it is based on Python, which is one of the most popular and widely used programming languages in the world.
    It is secure and provides features such as password hashing, session management, and CSRF protection to prevent common web attacks.
    It is flexible and extensible, as it allows you to customize and add functionality to your web application using various extensions and plugins that are available for Flask.
    It is scalable and can handle high traffic and large amounts of data using tools such as caching, load balancing, and cloud services.

# %%
# Q.2 Here is a screenshot of Flask application where function is written to display given output message.

# %% [markdown]
# ![Screenshot 2023-08-01 001334.png](data:image/png;base64,...)

# %%
"""Q.3
   App routing is the process of mapping a web page URL to a function that handles the logic and content for that page.
   For example, if you have a web page that displays a list of products, you can use app routing to link the URL /products to a function that queries the database and renders the HTML template for the products page. App routing in Flask is done using the @app.route decorator, which takes the URL as an argument and associates it with the function below it.
   App routing in Flask is useful for creating dynamic and user-friendly web applications, as it allows you to define different paths and parameters for different pages and functions. You can also use converters and defaults to specify the data type and value of the URL variables.

# %%
#Q.4 Here "/" route is given in url to display the details given in the question.

# %% [markdown]
# ![Screenshot 2023-08-01 000359.png](data:image/png;base64,...)

# %%
# Here "/welcome" route is used to display given welcome msg.

# %% [markdown]
# ![Screenshot 2023-08-01 000626.png](data:image/png;base64,...)

# %%
"""Q.5 The function that is used in Flask for URL building is url_for. URL building is the process of generating a URL from a view function name and optional parameters.
       For example, if you have a view function called test that takes a test_num as an argument, we can use url_for to generate a URL like /test/123 by passing the function name and the test_num as arguments.
       The url_for function is imported from the Flask module, and it returns a string that represents the URL.

       Here is the python code for url_for() function.

# %% [markdown]
# ![Screenshot 2023-08-01 001648.png](data:image/png;base64,...)
